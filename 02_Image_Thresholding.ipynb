# %% [markdown]
# <a href="https://colab.research.google.com/github/Prinjesh/Computer_vision/blob/main/02_Image_Thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Thresholding

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/content/sample_data/rainbow.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.imread('/content/sample_data/rainbow.jpg',0)

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# ## Different Threshold Types

# %% [markdown]
# ### Binary

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap='gray')

# %% [markdown]
# ### Binary Inverse

# %%
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh2,cmap='gray')

# %% [markdown]
# ###  Threshold Truncation

# %%
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
plt.imshow(thresh3,cmap='gray')

# %% [markdown]
# ### Threshold to Zero

# %%
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
plt.imshow(thresh4,cmap='gray')

# %% [markdown]
# ### Threshold to Zero (Inverse)

# %%
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
plt.imshow(thresh5,cmap='gray')
